# %% [markdown]
# ## Histograms

# %% [markdown]
# plotted using matplotlib's plt

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
import pandas as pd
data = load_breast_cancer() 

print(data.keys())
pd.DataFrame(data.data).sample(5, random_state=2049)
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
#         0      1       2       3        4        5        6        7       8   \
# 50   11.76  21.60   74.72   427.9  0.08637  0.04966  0.01657  0.01115  0.1495
# 161  19.19  15.94  126.30  1157.0  0.08694  0.11850  0.11930  0.09667  0.1741
# 255  13.96  17.05   91.43   602.4  0.10960  0.12790  0.09789  0.05246  0.1908
# 468  17.60  23.33  119.00   980.5  0.09289  0.20040  0.21360  0.10020  0.1696
# 507  11.06  17.12   71.25   366.5  0.11940  0.10710  0.04063  0.04268  0.1954
#
#           9   ...     20     21      22      23      24       25       26  \
# 50   0.05888  ...  12.98  25.72   82.98   516.5  0.1085  0.08615  0.05523
# 161  0.05176  ...  22.03  17.81  146.60  1495.0  0.1124  0.20160  0.22640
# 255  0.06130  ...  16.39  22.07  108.10   826.0  0.1512  0.32620  0.32090
# 468  0.07369  ...  21.57  28.87  143.60  1437.0  0.1207  0.47850  0.51650
# ...

# %%
plt.figure(figsize=(7,3))
plt.hist(data.data[:,0], bins=20)   # bins is for grouping of the datapoints in the graph
plt.xlabel("Mean Radius")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Looks like the data is roughly normally distributed

# %% [markdown]
# Now looking at the Frequency of the mean radius in malignant and benign samples

# %%
plt.figure(figsize=(7,3))
plt.hist(data.data[data.target==0,0], bins=20, alpha=0.5, label="Malignant")
plt.hist(data.data[data.target==1,0], bins=20, alpha=0.5, label="Benign")
# condition specifies to extract 1st feature of the target column
plt.xlabel("Mean Radius")
plt.ylabel("Frequency")
plt.legend()

plt.show()

# %% [markdown]
# So the radius of Malignant tumors is large compared to benign ones

# %% [markdown]
# ## Density plots

# %%
import seaborn as sns

# %%
plt.figure(figsize=(7,3))
sns.kdeplot(data.data[:,0], fill=True)
plt.xlabel("Mean Radius")
plt.ylabel("Density")
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.kdeplot(data.data[data.target==0,0], fill=True, label='Malignant')
sns.kdeplot(data.data[data.target==1,0], fill=True, label='Benign')
plt.xlabel("Mean Radius")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ## Correlation Matrix (or HeatMap)

# %% [markdown]
# Correlation coefficients are linear relationships between two variables, here its 2 features in the dataset.
#
# 1  -  positive correlation
#
# -1 -  negative correlation
#
# 0  -  no correlation

# %%
import numpy as np

df = pd.DataFrame(data.data, columns=data.feature_names)
target = data.target

plt.figure(figsize=(7.5, 3.5))

corr = df.corr()
sns.set_theme(style='white')
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(
    corr,
    mask=mask, 
    cmap=cmap, 
    vmax=.3, 
    center=0,
    square=True, 
    linewidths=.5, 
    cbar_kws={
        "shrink": .5
    }
    
)
plt.show()

# %% [markdown]
# ## Scatter Plot (or PairPlot)

# %%
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_iris


iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
target = iris.target

plt.figure(figsize=(7.5, 3.5))
corr = df.corr()
sns.set_theme(style='white')
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(
    corr,
    mask=mask, 
    cmap=cmap, 
    vmax=.3, 
    center=0,
    square=True, 
    linewidths=.5, 
    cbar_kws={
        "shrink": .5
    }
    
)
plt.show()

# %%
# create scatter matrix plot
iris = sns.load_dataset('iris')
sns.pairplot(iris, hue='species')

# show plot
plt.show()
